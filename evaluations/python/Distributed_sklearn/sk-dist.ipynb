# %%
# https://www.kdnuggets.com/2019/09/train-sklearn-100x-faster.html
# TBD needs installation of Spark before PySpark  https://medium.com/@naomi.fridman/install-pyspark-to-run-on-jupyter-notebook-on-windows-4ec2009de21f

# %%
import time
from sklearn import datasets, svm
from skdist.distribute.search import DistGridSearchCV
from pyspark.sql import SparkSession # instantiate spark session

# %%
spark = (   
    SparkSession    
    .builder    
    .getOrCreate()    
    )
sc = spark.sparkContext # the digits dataset

# %%
digits = datasets.load_digits()
X = digits["data"]
y = digits["target"] # create a classifier: a support vector classifier

# %%
classifier = svm.SVC()
param_grid = {
    "C": [0.01, 0.01, 0.1, 1.0, 10.0, 20.0, 50.0], 
    "gamma": ["scale", "auto", 0.001, 0.01, 0.1], 
    "kernel": ["rbf", "poly", "sigmoid"]
    }
scoring = "f1_weighted"
cv = 3 # hyperparameter optimization

# %%
start = time.time()
model = DistGridSearchCV(    
    classifier, param_grid,     
    sc=sc, cv=cv, scoring=scoring,
    verbose=True    
    )
model.fit(X,y)
print("Train time: {0}".format(time.time() - start))
print("Best score: {0}".format(model.best_score_))
# Out:
# Spark context found; running with spark
# Fitting 3 folds for each of 105 candidates, totalling 315 fits
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-8-cae4de97dec9> in <module>
#       5     verbose=True
#       6     )
# ----> 7 model.fit(X,y)
#       8 print("Train time: {0}".format(time.time() - start))
#       9 print("Best score: {0}".format(model.best_score_))
#
# C:\ProgramData\Anaconda3\lib\site-packages\skdist\distribute\search.py in fit(self, X, y, groups, **fit_params)
#     376             base_estimator_ = self.sc.broadcast(base_estimator)
#     377             partitions = _parse_partitions(self.partitions, len(fit_sets))
# --> 378             out = self.sc.parallelize(fit_sets, numSlices=partitions).map(lambda x: [x[0], _fit_and_score(
#     379                 base_estimator_, X, y, scorers, x[2][0], x[2][1],
# ...
