# %% [markdown]
# # Takaways
#
# * Too slow for larger datasets
# * Not production ready yet. Code seems to be in flux.
# * Hard to interpret the results and gather insights.

# %% [markdown]
# # Links
# * https://www.kdnuggets.com/2020/03/painlessly-analyze-time-series.html (this seems to be the latest code)
# * https://towardsdatascience.com/introduction-to-matrix-profiles-5568f3375d90 (the code associated with this article seems to be old)

# %%
import pandas as pd
import numpy as np
import time
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import matrixprofile as mp
import matrixprofile.algorithms.stomp as stomp

# %%
df = pd.read_csv('nyc_yellow_taxi_passenger_count_2018_hourly.csv')
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df = df.set_index('pickup_datetime').sort_index()

# %%
data = pd.read_csv('nyc_yellow_taxi_passenger_count_2018_hourly.csv')
data.head()
# Out:
#        pickup_datetime  passenger_count
# 0  2018-01-01 00:00:00            28630
# 1  2018-01-01 01:00:00            32778
# 2  2018-01-01 02:00:00            27966
# 3  2018-01-01 03:00:00            21243
# 4  2018-01-01 04:00:00            14822

# %%
vals = data.iloc[1:200]['passenger_count'].values
fig,ax = plt.subplots(figsize=(20,10))
ax.plot(np.arange(len(vals)),vals, label = 'Test Data')

# %%
start = time.time()
profile, figures = mp.analyze(vals)
end = time.time()
time_taken = end - start
time_taken
# Out:
# C:\Users\Nikhil\.conda\envs\dl_ts\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# C:\Users\Nikhil\.conda\envs\dl_ts\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# C:\Users\Nikhil\.conda\envs\dl_ts\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# 1.4750571250915527

# %%
profile, figures = mp.analyze(vals, windows=7)
# Out:
# C:\Users\Nikhil\.conda\envs\dl_ts\lib\site-packages\matrixprofile\visualize.py:375: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
